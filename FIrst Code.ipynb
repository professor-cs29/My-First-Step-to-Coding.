# %%
print("Hello. My name is Professor.")
# Out:
# Hello. My name is Professor.

# %%
print(28*19540)
# Out:
# 547120

# %%
print(True or False)
# Out:
# True

# %%
print(34.91 + 94.09)
# Out:
# 129.0
